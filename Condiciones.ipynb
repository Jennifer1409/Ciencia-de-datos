# %%
# Condciones

# INICIO
a = float(input("Ingrese a: \n"))
b = float(input("Ingrese b: \n"))

# Empieza la condición.
if (b != 0):
    c = a/b
    print("Resultado: ", c)

# Termina la condición.

# FIN
# Out:
# Ingrese a:
# 3
# Ingrese b:
# 3
# Resultado:  1.0

# %%
# Condción lógica

# INICIO

checar = False
a = float(input("Ingrese a: \n"))
b = float(input("Ingrese b: \n"))

# Empieza la condición.
if (b != 0):
    checar = True

# Empieza la condición.
if (checar):
    c = a/b
    print("Resultado: ", c)

# Termina la condición.

# FIN
# Out:
# Ingrese a:
# x
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-6-e9d9d3b1db6f> in <module>()
#       4
#       5 checar = False
# ----> 6 a = float(input("Ingrese a: \n"))
#       7 b = float(input("Ingrese b: \n"))
#       8
#
# ValueError: could not convert string to float: 'x'

# %%
# Ecuación de primer grado.

#INICIO

# Entrada de datos:
a = float(input("Dame a: \n"))
b = float(input("Dame b: \n"))

# Condición
if ( a != 0):
    x = -b/a
    print("Resultado: ", x)
# Fin de la condición y cálculo de x.

#FIN
# Out:
# Dame a:
# 3
# Dame b:
# 4
# Resultado:  -1.3333333333333333

# %%
# Evaluación de expresiones lógicas.

# INICIO
a = True
b = True
c = 23.2
d = -18.34
e = -98

# Despliegue de resultados:
print( "\n a and b = ", a and b)
print( "\n a and not b = ", a and not b)
print( "\n c > d ", c > d)
print( "\n c < e & e < d = ", c < e & e < d)
print( "\n c < e or a == b = ", c < e or a == b)
print( "\n not(c > e) = ", not(c > e))
print( "\n a  = ", a )
# Out:
#  a and b =  True
#
#  a and not b =  False
#
#  c > d  True
#
#  c < e & e < d =  False
#
#  c < e or a == b =  True
#
#  not(c > e) =  False
#
#  a  =  True

# %%
# Compuestos químicos

# INICIO

a = input("\nDame la fórmula: ")

if(a == 'NCl'):
    print("\nSal común")
# Fin de la condición.

if(a == 'H2O'):
    print("\nAgua")
# Fin de la condición.

if(a == 'HCl'):
    print("\nÁcido clorhídrico")
# Fin de la condición.

#FIN
# Out:
# Dame la fórmula: H2O
#
# Agua

# %%
# Ecuación de segundo grado.
# Se importa la biblioteca math
from math import *

# INICIO

a = float(input("\nDame a: "))
b = float(input("\nDame b: "))
c = float(input("\nDame c: "))

# Calcular discriminante:
d = pow(b, 2) - 4*a*c

# Calcular raíces:
if (d > 0):
    print("\nRaíces reales y diferentes")
    x1 = (-b + sqrt(d))/2/a
    x2 = (-b - sqrt(d))/2/a
    print("\nLa primera raíz es ", x1)
    print("\nLa segunda raíz es ", x2)
# Fin de la condición

if (d == 0):
    print("\nRaíces reales e iguales")
    x1 = -b/2/a
    x2 = x1
    print("\nLa primera raíz es ", x1)
    print("\nLa segunda raíz es ", x2)
# Fin de la condición.

if (d < 0):
    print("\nRaíces complejas conjugadas")
    x1_parte_real = -b/2/a
    x1_parte_imaginaria = sqrt(-d)/2/a
    x2_parte_real = x1_parte_real
    x2_parte_imaginaria = -x1_parte_imaginaria
    print("\nLa primera raíz es ", x1_parte_real," + j ", x1_parte_imaginaria)
    print("\nLa segunda raíz es ", x2_parte_real, " - j ", -x2_parte_imaginaria)
# Fin de la condición

#FIN
# Out:
# Dame a: 2
#
# Dame b: 3
#
# Dame c: 5
#
# Raíces complejas conjugadas
#
# La primera raíz es  -0.75  + j  1.3919410907075054
#
# La segunda raíz es  -0.75  - j  1.3919410907075054

# %%
''' Ecuación de primer grado,
    Uso de if-else.'''

#INICIO

# Entrada de datos:
a = float(input("Dame a: \n"))
b = float(input("Dame b: \n"))

# Condición
if ( a != 0):
    c = -b/a
    print("Resultado: ", c)
else:
    print("La división no se puede realizar.")
# Fin del if-else

#FIN
# Out:
# Dame a:
# 3
# Dame b:
# 4
# Resultado:  -1.3333333333333333

# %%
# Cálculo del saldo

#INICIO

print('Dame el saldo actual')
Saldo = float(input( ))

# Empieza la condición.
if( Saldo < 10000.00):
    Saldo = Saldo*(1 + 0.03)
else:
    Saldo = Saldo*(1 + 0.04)
# Fin del if-else.

print("\nEl saldo final es ", Saldo)

# FIN
# Out:
# Dame el saldo actual
# 1000
#
# El saldo final es  1030.0

# %%
# Ecuación de primer grado.

#INICIO

# Entrada de datos:
a = float(input("Dame a: \n"))
b = float(input("Dame b: \n"))

# Condición
if ( a != 0):
    x = -b/a
    print("Resultado: ", x)
else:
    if ( b == 0):
        print("a = 0 y b = 0")
    else:
        print("No hay solución")
    # Fin del if anidado.
# Fin del if inicial.

#FIN
# Out:
# Dame a:
# 1
# Dame b:
# -1
# Resultado:  1.0

# %%
# Cálculo del saldo

#INICIO

print('Dame el saldo actual')
Saldo = float(input( ))

# Empieza la condición.
if( Saldo < 10,000.00 ):
    Saldo = Saldo*(1 + 0.03)
elif ( Saldo < 100,000.00 ):
    Saldo = Saldo*(1 + 0.04)
else:
    Saldo = Saldo*(1 + 0.06)
    # Fin del if anidado.
# Fin del if inicial.

print("\nEl saldo final es ", Saldo)

# FIN
# Out:
# Dame el saldo actual
# 200000000
#
# El saldo final es  206000000.0

# %%
# Calificaciones numéricas.

# INICIO

# Recibe la calificación.
calificacion = float(input("Dame una calificación: "))

# Inicio de la condición:
if calificacion > 9.0:
    print("\nLa calificación es A.")
elif(calificacion > 8.0):
    print("\nLa calificación es B.")
elif(calificacion >= 7.5):
    print("\nLa calificación es C.")
else:
    print("\nLa calificación es R.")

#Fin de la condición anidada.

#FIN
# Out:
# Dame una calificación: 10
#
# La calificación es A.

# %%
# Condición con variables lógicas.

#INICIO

c = float(input("Dame un valor numérico de c: "))
print("\nPara dar un valor de False en una variable Booleana")
print("\nno escribir nada y dar Enter")
a = bool(input("Dame un valor lógico de a (True o False): "))

print("\nEl valor de a es ", a)
if(a):
    B = 3*c
else:
    B = c + 1
# Fin del si

print("\nEl valor de B es ", B)

# FIN
# Out:
# Dame un valor numérico de c: 3
#
# Para dar un valor de False en una variable Booleana
#
# no escribir nada y dar Enter
# Dame un valor lógico de a (True o False): nada
#
# El valor de a es  True
#
# El valor de B es  9.0

# %%
# Calificaciones numéricas y asistencia.

# INICIO

# Recibe la calificación y la asistencia.
calificacion = float(input("Dame una calificación: "))
print("\nDame la asistencia: 1 si asistió, 0 si no asistió.")
asistencia = bool(input( ))

# Inicio de la condición:
if (calificacion > 9.0 and asistencia == 1):
    print("\nLa calificación es A Excelente con Mención Honorífica.")
elif (calificacion > 9.0 and asistencia != 1):
    print("\nLa calificación es A Excelente.")
elif(calificacion > 8.0 and asistencia == 1):
    print("\nLa calificación es B Muy Bien con Mención Honorífica.")
elif(calificacion > 8.0 and asistencia != 1):
    print("\nLa calificación es B Muy Bien.")
elif(calificacion >= 7.5):
    print("\nLa calificación es C.")
else:
    print("\nLa calificación es R.")

#Fin de la condición anidada.

#FIN
# Out:
# Dame una calificación: 6
#
# Dame la asistencia: 1 si asistió, 0 si no asistió.
# 1
#
# La calificación es R.

# %%
# Calculadora básica con menú.

# Se importa la biblioteca math:
from math import log

# INICIO
bandera = False
x = float( input("\nDame el valor del número x: "))
y = float( input("\nDame el valor del número y: "))
print("\nDame la opción que deseas realizar:\n")

# Se despliega el menú para seleccionar la opción que deseas realizar:
print(" 1) Sumar ( El primero más el segundo)")
print(" 2) Restar ( El primero más el segundo)")
print(" 3) Multiplicar ( El primero más el segundo)")
print(" 4) Dividir ( El primero más el segundo)")
print(" 5) Potencia ( El primero más el segundo)")
print(" 6) Logaritmo ( El primero más el segundo)")

opcion = int(input( ))

# Empieza la ejecución del menú con condiciones anidadas.
if (opcion == 1):
    z = x + y
    print(x, "+", y)
elif (opcion == 2):
    z = x - y
    print(x, "-", y)
elif (opcion == 3):
    z = x * y
    print(x, "*", y)
elif (opcion == 4 and y != 0):
    z = x / y
    print(x, "/", y)
elif (opcion == 4 and y == 0):
    print("\nEl denominador es igual a cero y")
    print("\nNO se puede realizar la división.")
    bandera = True
elif (opcion == 5):
    z = pow(x, y)
    print(x, "^", y)
elif (opcion == 6 and x > 0):
    z = log(x)
    print("logaritmo de ", x)
elif (opcion == 6 and x < 0):
    print("\nEl valor de x es <= 0 y")
    print("\nNO se puede calcular el logaritmo.")
    bandera = True
else:
    print("Opción desconocida.")
# Se terminan las condiciones anidadas.

# Se escribe el resultado con otra condición:
if (opcion < 7 and bandera == False):
    print("Resultado = ", z)

# FIN
# Out:
# Dame el valor del número x: 3
#
# Dame el valor del número y: 5
#
# Dame la opción que deseas realizar:
#
#  1) Sumar ( El primero más el segundo)
#  2) Restar ( El primero más el segundo)
#  3) Multiplicar ( El primero más el segundo)
#  4) Dividir ( El primero más el segundo)
#  5) Potencia ( El primero más el segundo)
#  6) Logaritmo ( El primero más el segundo)
# 2
# 3.0 - 5.0
# Resultado =  -2.0
